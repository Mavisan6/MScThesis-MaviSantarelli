# %% [markdown]
# # Data Gathering and Processing: Occurrence Data
# This phase focuses on acquiring and processing species occurrence data for *Rana temporaria* (Common Frog), *Bufo bufo* (Common Toad), and the three native newts present in Scotland: *Lissotriton helveticus* (Palmate Newt), *Lissotriton vulgaris* (Smooth Newt), and *Triturus cristatus* (Great Crested Newt). The goal is to obtain high-resolution or presence/absence data for use in habitat suitability modeling, ecological network analysis, and ultimately in developing recommendations for Blue-Green Infrastructure (BGI) opportunities that enhance amphibian connectivity.
#
# ## 1. Importance of Occurrence and Presence/Absence Data
# ### 1.1 Occurrence Data:
#
# **Definition**: This data represents the locations where a particular species has been observed or recorded. It usually includes geographic coordinates, dates, and other associated metadata.
#
# **Use in This Study**: Occurrence data is a primary input for building habitat suitability models using species distribution modeling (SDM) approaches. These models predict the suitability of areas within the study region based on environmental predictors (more on environmental predictors in LINK TO NOTEBOOK). Occurrence data is also used in spatial analyses to identify ecological corridors and areas with connectivity potential for the species in focus.
#
# ### 1.2 Presence/Absence Data:
#
# **Definition**: Presence/absence data indicates whether a species is present or not at particular locations within a defined grid or area. Unlike occurrence data, it also explicitly captures areas where the species was not found, providing a more robust basis for certain statistical modelling approaches.
#
# **Use in This Study:** This data helps refine models by providing negative data points (absence data), which can improve the reliability and accuracy of habitat suitability models. Presence/absence data can aid in assessing the effectiveness of existing ecological networks and identifying areas that need enhancement or restoration through BGI.

# %% [markdown]
# ## 2. Species Occurrence Retrieval
# Species occurrence data was retrieved from the **NBN Atlas**, a widely recognized resource for biodiversity data in the United Kingdom. The NBN Atlas offers an extensive repository of species occurrence records, contributed by various organizations, research initiatives, and citizen science projects. The platform ensures that data is both comprehensive and quality-checked, making it a reliable choice for ecological studies.
#
# The NBN Atlas is particularly advantageous for this study due to its user-friendly interface and robust filtering capabilities, allowing researchers to refine queries based on species, date, geographic area, and data quality. Additionally, the NBN Atlas includes metadata that supports evaluating the credibility and origin of records, a critical aspect when integrating data into modelling workflows.
#
# The species data retrieved will be crucial for constructing habitat suitability models, as it provides georeferenced locations where the target species have been observed. These records will serve as **"presence"** data points for model training, complemented by **pseudo-absence data** generated across the study area. Ensuring high-quality occurrence data from the NBN Atlas will enhance the reliability and accuracy of subsequent analyses. Prior to their inclusion in the modelling phase, the records will be processed to ensure consistency and quality. This step involves validating spatial accuracy, removing duplicates, and ensuring that all occurrences fall within the study area boundaries. By addressing potential data inconsistencies, the processed dataset will better support the development of robust and reliable models.
#
# The dataset was downloaded in `CSV format`, including occurrence records for the target amphibian species (**Rana temporaria**, **Bufo bufo**, and selected newt species such as **Lissotriton helveticus**, **Lissotriton vulgaris**, and **Triturus cristatus**). The CSV files were first loaded in ArcGIS Pro, for a preliminary inspection, and were clipped to the study area. Furher filtering and processing of the data is carried out in the sections below.
#
# ### 2.1 Importing Required Data and Libraries
# Let's begin by importing essential libraries for data retrieval and geospatial analysis. Below we are also importing the downloaded NBN occurrence dataset for further filtering and processing.

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Load the shapefile into a GeoDataFrame
shapefile_path = "C:/GIS_Course/MScThesis-MaviSantarelli/data/OccurrenceData/NBN_Atlas_Occurrences.shp"  # Update with the actual path to your shapefile
gdf = gpd.read_file(shapefile_path)

# %% [markdown]
# In the code above:
#
# * `geopandas` facilitates geospatial operations, such as loading and filtering data based on a shapefile.
# * `matplotlib` is used for data visualisation and plotting.
#
# ### 2.2 Loading the Study Area Shapefile
# Below we are also loading the study area for this study.

# %%
# Load study area shapefile
study_area = gpd.read_file('C:/GIS_Course/MScThesis-MaviSantarelli/data/StudyArea/Study_Area.shp')

# %% [markdown]
# ### 2.3 Inspecting the Occurrence Dataset
#
# We use the code below to inspect the NBN Occurrence Data, querying for summary information about the shapefile. This allows us to learn the columns contained in the shapefile so that we can filter the data accordingly.

# %%
# Get summary information about the shapefile
print("\nShapefile info:")
print(gdf.info())
# Out:
# Shapefile info:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 9652 entries, 0 to 9651
# Data columns (total 67 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NBN_Atlas_  9652 non-null   object
#  1   Occurrence  9652 non-null   object
#  2   Licence     9652 non-null   object
#  3   Rightshold  9643 non-null   object
#  4   Scientific  9652 non-null   object
#  5   Taxon_auth  9652 non-null   object
#  6   Name_quali  0 non-null      object
#  7   Common_nam  9652 non-null   object
#  8   Species_ID  9652 non-null   object
#  9   Taxon_Rank  9652 non-null   object
#  10  Occurren_1  9652 non-null   object
#  11  Start_date  7689 non-null   object
#  12  Start_da_1  9652 non-null   int64
#  13  Start_da_2  9652 non-null   int64
#  14  Start_da_3  9652 non-null   int64
#  15  End_date    128 non-null    object
#  16  End_date_d  9652 non-null   int64
#  17  End_date_m  9652 non-null   int64
# ...

# %% [markdown]
# Based on the shapefile information provided, the relevant columns for species occurrences and dates seem to be:
#
# * **Species column**: `Scientific` (contains scientific names).
# * **Occurrence column**: `Occurrence` (occurrence ID).
# * **Start date column**: `Start_date` (useful for filtering by date).
# * **Latitude and Longitude**: `Latitude__` and `Longitude_` (used for plotting the data).
#
# The code below uses these columns to calculate some statics about the data:

# %%
# Count occurrences by species
species_column = 'Scientific'  # Column name for species
occurrence_column = 'Occurrence'  # Column name for occurrence ID

occurrences_by_species = gdf[species_column].value_counts()

# Plot a bar chart of occurrences by species
plt.figure(figsize=(10, 6))
ax = occurrences_by_species.plot(kind='bar', color='skyblue')

# Adding count numbers on top of each bar
for i, count in enumerate(occurrences_by_species):
    ax.text(i, count + 10, str(count), ha='center', va='bottom', fontsize=10)  # Adjust the 10 for spacing

# Customize the plot
plt.title('Occurrences by Species')
plt.xlabel('Species')
plt.ylabel('Number of Occurrences')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Lastly, we are inspecting the date range and some basic spatial info using the column `Start_date` and the functions `crs` and `tota_ bounds`.

# %%
import pandas as pd

# If there is a 'Start_date' column, show the date range
if 'Start_date' in gdf.columns:
    print("\nDate range:")
    # Ensure 'Start_date' is in datetime format
    gdf['Start_date'] = pd.to_datetime(gdf['Start_date'], errors='coerce')
    print(f"Start date: {gdf['Start_date'].min()}")
    print(f"End date: {gdf['Start_date'].max()}")
else:
    print("\nNo 'Start_date' column found in the shapefile.")

# Optional: Show basic spatial info (bounds, CRS, etc.)
print("\nSpatial Information:")
print(gdf.crs)  # Coordinate Reference System
print(gdf.total_bounds)  # Bounding box of the data
# Out:
# Date range:
# Start date: 1885-07-18 00:00:00
# End date: 2024-10-19 00:00:00
#
# Spatial Information:
# EPSG:4326
# [-5.052678   54.862494   -2.233571   56.46817964]

# %% [markdown]
# ## 3. Considerations on Data Quality and Resolution
# When using species occurrence data, particularly from sources like the NBN Atlas, ensuring the data quality is crucial for producing reliable and meaningful results in biodiversity modeling. The quality of the data influences model accuracy, reliability, and the subsequent conservation planning and decision-making processes. Below are some key factors to consider regarding data quality and steps you can take to ensure the robustness of your models:
#
# ### 3.1. Accuracy of Location Data
# 1. **Coordinates**: Accurate geographic coordinates (latitude, longitude) are essential for modeling species distributions. Any discrepancies in location data can lead to inaccurate predictions, especially if points fall outside the true range of the species.
# 2. **Spatial Resolution**: Occurrence data should have high spatial resolution (accurate location data) to avoid model over-simplifications. Points that are recorded with very broad or coarse spatial resolution will dilute the effectiveness of habitat suitability models.
# 3. **Data Source**: In the NBN Atlas, we can inspect columns like `Latitude_`, `Longitude_`, or `OSGR codes` (for grid references) to evaluate the spatial accuracy.
#
# ### 3.2 Temporal Relevance
# 1. **Date Range**: Data used for species distribution modeling should represent a relevant time period to account for seasonal variations, life cycle patterns, and environmental changes that might affect species presence.
# 2. **Temporal Consistency**: Outdated data may fail to represent current species distributions, especially if the habitat or environmental conditions have changed significantly.
# 3. **Data Source**: Columns like `Start_date` or `Start_da_1`, which contain the date when the observation was made, can help in filtering for the relevant time period.
#
# ### 3.3 Verification of Occurrences
# 1. **Occurrence Validation**: It's important to distinguish between verified and unverified species occurrences. Unverified data (often marked as "unidentified" or "incomplete") can introduce bias or errors in models.
# 2. **Taxonomic Precision**: The taxonomy needs to be verified, and the data should include the correct species names to ensure that the records are associated with the correct species.
# 3. **Data Source**: Columns like `Identifica` (identification status), `Taxon_Rank`, or `Taxon_auth` (taxonomy authority) can help identify verified occurrences.
#
# ### 3.4 Completeness
# 1. **Missing Data**: Missing values in key columns, such as `Latitude_`, `Longitude_`, or `Start_date`, should be dealt with appropriately. Data gaps can affect model reliability, especially if missing values are frequent or concentrated in certain areas.
# 2. **Other Variables**: Ensure that data such as `Recorder` and `Determiner` are not missing when they pertain to data quality.
# 3. **Data Source**: Inspect missing values using `.isnull()` for columns like `Latitude_`, `Longitude_`, and `Start_date` to assess completeness.

# %% [markdown]
# ## 4. Data Processing
# ### 4.1 Filtering for Verified Occurrences
# Before filtering out unverified records, we can use the `.value_counts()` method to count how many unverified records there are based on the Identifica column.

# %%
verification_counts = gdf['Identifica'].value_counts()
print("Verification Status Counts:\n", verification_counts)
# Out:
# Verification Status Counts:
#  Identifica
# Accepted - considered correct    3513
# Unconfirmed - not reviewed       2578
# Accepted                         1986
# Accepted - correct               1282
# Unconfirmed - plausible           243
# Unconfirmed                        50
# Name: count, dtype: int64

# %% [markdown]
# Based on the verification status counts provided, it seems that the `Identifica` column includes several categories such as 'Accepted', 'Unconfirmed', and others with different levels of confidence. To filter for verified records, we should first determine which categories are to be considered as "verified". From the given values, the following categories are likely acceptable for inclusion in the dataset:
#
# * **'Accepted - considered correct'**
# * **'Accepted'**
# * **'Accepted - correct'**
#
# The other categories (e.g., 'Unconfirmed', 'Unconfirmed - not reviewed', 'Unconfirmed - plausible') would be considered unverified. We can now filter the data as below:

# %%
# Define what categories are considered verified
verified_categories = ['Accepted - considered correct', 'Accepted', 'Accepted - correct']
# Count how many unverified records are present
unverified_count = verification_counts.loc[
    verification_counts.index.str.contains('Unconfirmed', case=False, na=False)].sum()

print(f"\nNumber of unverified records: {unverified_count}")

# Filter the data to keep only the verified records
verified_data = gdf[gdf['Identifica'].isin(verified_categories)]  # Filter for accepted categories

# Check the number of records after filtering
print(f"\nNumber of verified records: {verified_data.shape[0]}")
# Out:
# Number of unverified records: 2871
#
# Number of verified records: 6781

# %% [markdown]
# We can see that a total of 6781 records got deleted as they were found to be unverified and therefore potentially inaccurate records.
#
# ### 4.2 Temporal Filtering
# #### Justification for the Selected Temporal Range (2014–2024)
# Temporal filtering ensures the inclusion of records within the selected range, reducing bias from historical or outdated data. To model amphibian distribution accurately, occurrence data from a 10-year period (2014–2024) was selected. This temporal range strikes a balance between capturing sufficient data for statistical robustness and ensuring ecological relevance. Amphibians are particularly sensitive to environmental fluctuations such as habitat fragmentation and climate change. Given their relatively slow population dynamics, a 10-year period accommodates natural variability in breeding cycles and population trends, offering a more stable and reliable foundation for modeling. Furthermore, this range is consistent with studies that emphasize the importance of incorporating multiple years to account for both short-term fluctuations and long-term ecological trends (Guisan & Thuiller, 2005; Olsen, 2006; Zaniewski et al., 2002).

# %%
# Convert 'Start_date' to datetime format
verified_data['Start_date'] = pd.to_datetime(verified_data['Start_date'], errors='coerce')

# Filter records for the temporal consistency (2014 to 2024)
verified_and_temporal_filtered = verified_data[(verified_data['Start_date'].dt.year >= 2014) & 
                                               (verified_data['Start_date'].dt.year <= 2024)]

# Check the number of records after filtering
print(f"\nNumber of verified and temporally filtered records: {verified_and_temporal_filtered.shape[0]}")

# Optionally, check the range of dates in the filtered data
print("Date Range in the filtered data:", verified_and_temporal_filtered['Start_date'].min(), "to", verified_and_temporal_filtered['Start_date'].max())
# Out:
# Number of verified and temporally filtered records: 2508
# Date Range in the filtered data: 2014-02-22 00:00:00 to 2024-10-05 00:00:00
# C:\Users\M533\anaconda3\envs\MscThesis\lib\site-packages\geopandas\geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %% [markdown]
# ### 4.3 Ensuring Spatial Resolution
#
# This section focuses on ensuring the spatial resolution is correct by removing records with missing coordinates or duplicate locations. Checking the number of decimal places in latitude and longitude coordinates helps assess the spatial resolution or precision of the data. Coordinates with more decimal places provide a more precise location, while fewer decimal places result in a coarser location. 4 decimal places in latitude and longitude typically represent a precision of about 10 meters, which is often sufficient for many ecological studies, such as tracking species occurrences in a general area.

# %%
# Filter records based on latitude and longitude precision (e.g., 5 or more decimal places):
spatial_filtered_data = verified_and_temporal_filtered[
    verified_and_temporal_filtered['Latitude_L'].apply(lambda x: len(str(x).split('.')[-1]) >= 4) &
    verified_and_temporal_filtered['Longitude_'].apply(lambda x: len(str(x).split('.')[-1]) >= 4)
]

# Check how many records are left after applying spatial filtering
print(f"Number of records after spatial filtering: {spatial_filtered_data.shape[0]}")
# Out:
# Number of records after spatial filtering: 2505

# %% [markdown]
# ### 4.4 Checking for Duplicates

# %%
# Check for exact duplicate rows across all columns
duplicates_all_columns = spatial_filtered_data[spatial_filtered_data.duplicated()]

# Print the number of duplicates and the actual rows
print(f"Number of exact duplicate rows: {duplicates_all_columns.shape[0]}")
print(duplicates_all_columns)
# Out:
# Number of exact duplicate rows: 0
# Empty GeoDataFrame
# Columns: [NBN_Atlas_, Occurrence, Licence, Rightshold, Scientific, Taxon_auth, Name_quali, Common_nam, Species_ID, Taxon_Rank, Occurren_1, Start_date, Start_da_1, Start_da_2, Start_da_3, End_date, End_date_d, End_date_m, End_date_y, Locality, OSGR, Latitude__, Longitude_, Coordinate, Verbatim_d, Recorder, Determiner, Individual, Abundance, Abundance_, Organism_s, Organism_r, Sex, Life_stage, Occurren_2, Identifica, Basis_of_r, Survey_key, Dataset_na, Dataset_ID, Data_provi, Data_pro_1, Institutio, Kingdom, Phylum, Class, Order_, Family, Genus, OSGR_100km, OSGR_10km, OSGR_2km, OSGR_1km, Country, State_Prov, Vitality, Country_in, Latitude_L, First_of_t, First_of_1, Geodetic_d, grid_Refer, Incomplete, Invalid_co, Occurren_3, coordina_1, geometry]
# Index: []
#
# [0 rows x 67 columns]

# %% [markdown]
# The code found 0 exact duplicates, we can explore this further by only search for duplciates in the main columns.

# %%
# Check for duplicate rows based on 'Longitude_', 'Latitude_L', 'Scientific', and 'Start Date'
duplicate_occurrences = spatial_filtered_data.duplicated(subset=['Longitude_', 'Latitude__', 'Scientific', 'Start_date'])

# Filter for duplicate entries
duplicate_entries = spatial_filtered_data[duplicate_occurrences]

# Print the number of duplicate entries
print(f"Number of duplicate entries with the same coordinates, species, and start date: {duplicate_entries.shape[0]}")
# Out:
# Number of duplicate entries with the same coordinates, species, and start date: 216

# %% [markdown]
# Now, we found that there exist 216 total duplicates with same values for coordinates, date of recording and species recorded. We can further investigate the origin of these duplicates using the code below by:
# 1. **Identifying duplicate entries**: The code works by first finding the duplicate entries in the dataset, based on columns like `Longitude_`, `Latitude__`, `Scientific`, and `Start_date`.
# 2. **Grouping by certain columns**: After identifying the duplicates, the code groups the dataset by these columns (`Longitude_`, `Latitude__`, `Scientific`, `Start_date`). So, it will consider rows with the same values in these four columns as a group.
# 3. **Checking for differences**: The `lambda x: x.nunique() > 1` part checks how many unique values exist in each column for each group. Specifically, it:
#     * For each group (i.e., rows with the same values for `Longitude_`, `Latitude__`, `Scientific`, `Start_date`), checks the number of unique values for every other column.
#     * If any column within that group has more than one unique value (i.e., if there are differences in that column for the rows grouped together), it will return `True`. Otherwise, it returns `False`.
# 4. **Filtering columns with differences**: The `different_columns.any(axis=1)` part then filters out groups of rows where there are no differences (i.e., where all the columns have the same value in all duplicate entries). It keeps only the groups where there are differences in at least one of the columns.
# 5. **Displaying the results**: Finally, the `print(columns_with_difference)` will display which columns have differences in their values for duplicate records.

# %%
# Check which columns differ across duplicate entries
different_columns = duplicate_entries.groupby(
    ['Longitude_', 'Latitude__', 'Scientific', 'Start_date']
).apply(lambda x: x.nunique() > 1)

# Identify the rows where there are any differences
columns_with_difference = different_columns[different_columns.any(axis=1)]

# List the column names that differ for each group
columns_with_true = columns_with_difference.apply(lambda row: row[row].index.tolist(), axis=1)

# Display the results
columns_with_true
# Out:
# C:\Users\M533\AppData\Local\Temp\ipykernel_31612\576276441.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   different_columns = duplicate_entries.groupby(
# Longitude_  Latitude__  Scientific              Start_date
# -4.483730   55.623200   Lissotriton helveticus  2016-04-08                             [NBN_Atlas_, Occurrence]
# -4.481499   55.626136   Lissotriton helveticus  2017-03-23            [NBN_Atlas_, Occurrence, Individual, Sex]
# -4.422091   54.955476   Bufo bufo               2014-07-13                             [NBN_Atlas_, Occurrence]
# -4.381004   55.313362   Bufo bufo               2020-06-23                             [NBN_Atlas_, Occurrence]
# ...

# %% [markdown]
# Duplicate records often arise due to differences in additional attributes recorded by different data sources or during separate submissions. In the results, columns listed (e.g., `Occurrence`, `Individual`, `Sex`, or `Life_stage`) indicate fields with inconsistencies among duplicate entries. Detecting and analyzing duplicates is essential to ensure data integrity and avoid biases in ecological modeling. Duplicates can inflate species presence counts or introduce inconsistencies if differing attribute values are not reconciled.
#
# In this study, species presence data is analyzed to model habitat suitability and ecological connectivity. The objective is to focus on species presence versus absence rather than species richness. Duplicate records, identified as entries with identical coordinates, species, and collection dates, do not add new information about presence but can artificially inflate the data, potentially leading to biased results in habitat suitability models.
#
# To address this, duplicate entries were removed by retaining only the first occurrence of each group of duplicates. This approach ensures the dataset accurately represents species distribution while avoiding overrepresentation of duplicate occurrences. By simplifying the dataset to unique records of presence, the analysis remains robust and computationally efficient without compromising ecological validity.

# %%
# Retain only the first occurrence for each group of duplicates
deduplicated_data = spatial_filtered_data.drop_duplicates(subset=['Longitude_', 'Latitude__', 'Scientific', 'Start_date'], keep='first')

# Print the number of rows after deduplication
print(f"Number of rows after removing duplicates: {deduplicated_data.shape[0]}")
# Out:
# Number of rows after removing duplicates: 2289

# %% [markdown]
# ## 5. Visualising the Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

# Step 1: Plotting a Bar Chart for Occurrences by Species
# Group the data by 'Scientific' or the relevant species column
species_counts = deduplicated_data['Scientific'].value_counts()

# Plotting the bar chart without using the deprecated 'palette' parameter
plt.figure(figsize=(10, 6))
ax = sns.barplot(x=species_counts.index, y=species_counts.values)

# Add count labels at the top of each bar
for i, count in enumerate(species_counts.values):
    ax.text(i, count + 0.05, str(count), ha='center', va='bottom', fontsize=10)

plt.title('Occurrences by Species (Filtered Data)')
plt.xlabel('Species')
plt.ylabel('Number of Occurrences')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Reproject spatial_filtered_data to match the CRS of your study area (EPSG:27700)
deduplicated_data_gdf = deduplicated_data.to_crs(study_area.crs)

# Plot the study area and filtered data points
fig, ax = plt.subplots(figsize=(10, 10))
study_area.plot(ax=ax, color='lightgrey', edgecolor='black')  # Plot the study area
deduplicated_data_gdf.plot(ax=ax, markersize=5, color='blue', alpha=0.5, label='Species Occurrences')  # Plot the filtered species data

# Add title, legend, and labels
ax.set_title('Species Occurrences within Study Area')
ax.set_xlabel('Eastings (m)')
ax.set_ylabel('Northings (m)')
plt.legend(title='Species', loc='upper left', bbox_to_anchor=(1, 1))

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Let's check again the distribution of records per species:

# %% [markdown]
# ____________________
# ___________________
#
# This part is just saving the dataset created so far.

# %%
import geopandas as gpd
import os

# Define the output directory for saving shapefiles
output_directory = "C:/GIS_Course/MScThesis-MaviSantarelli/data/OccurrenceData/OccurrenceDataperSpecies"
os.makedirs(output_directory, exist_ok=True)

# Initialize a dictionary to store the count of records per species
record_counts = {}

# Convert datetime fields to string format to ensure compatibility with Shapefile
if 'Start_date' in deduplicated_data.columns:
    deduplicated_data['Start_date'] = deduplicated_data['Start_date'].astype(str)

# Group the deduplicated data by species and save each as a shapefile
for species, group in deduplicated_data.groupby('Scientific'):
    # Create a GeoDataFrame for the species group
    species_gdf = gpd.GeoDataFrame(group, geometry=group.geometry, crs=deduplicated_data.crs)
    
    # Generate a valid filename for the species
    filename = f"{species.replace(' ', '_')}.shp"
    
    # Save the shapefile
    species_gdf.to_file(os.path.join(output_directory, filename))
    
    # Store the record count for the species
    record_counts[species] = len(species_gdf)
    
    print(f"Saved shapefile for {species} as {filename}")

# Display the count of records for each species
print("\nRecord counts for each species:")
for species, count in record_counts.items():
    print(f"{species}: {count} records")

print("\nShapefiles saved for all species.")
# Out:
# C:\Users\M533\anaconda3\envs\MscThesis\lib\site-packages\geopandas\geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# Saved shapefile for Bufo bufo as Bufo_bufo.shp
# Saved shapefile for Ichthyosaura alpestris as Ichthyosaura_alpestris.shp
# Saved shapefile for Lissotriton helveticus as Lissotriton_helveticus.shp
# Saved shapefile for Lissotriton vulgaris as Lissotriton_vulgaris.shp
# Saved shapefile for Rana temporaria as Rana_temporaria.shp
# Saved shapefile for Triturus cristatus as Triturus_cristatus.shp
#
# Record counts for each species:
# Bufo bufo: 716 records
# Ichthyosaura alpestris: 33 records
# Lissotriton helveticus: 337 records
# Lissotriton vulgaris: 60 records
# ...

# %% [markdown]
# This part just saved the dataset created so far.
# ____________________________________
# _________________

# %% [markdown]
# ## 5. Generating Pseudo-Absences
# ### Importance of Pseudo-Absences and the Choice Behind the Number of Absences
#
# In species distribution modeling (SDM), pseudo-absences are used to represent locations where the species is assumed to be absent. Since species occurrence data often consists only of presence records, pseudo-absences are essential for training models that distinguish between areas where a species is likely to occur and those where it is unlikely. The quality and number of pseudo-absences are critical to the performance and accuracy of SDMs. If pseudo-absences are poorly chosen, the model may be biased or fail to accurately predict species distributions.
#
# The **choice of the number of pseudo-absences** is a key aspect in developing reliable SDMs. Too few pseudo-absences may result in models that are overfit to the presence data, making them unreliable in predicting absence patterns (Barbet-Massin et al., 2012). Conversely, using too many pseudo-absences could lead to a loss of predictive power and potential overgeneralization, especially if the pseudo-absences are not adequately representative of the species' potential range.
#
# Research suggests that the number of pseudo-absences should vary depending on the **modeling technique**. For **regression models** like Generalized Linear Models (GLMs) and Generalized Additive Models (GAMs), larger numbers of pseudo-absences (between 10 to 15 times more than presence records) are typically recommended to balance the influence of environmental predictors and presence data (Elith et al., 2011). In contrast, more complex machine learning models like **Random Forest** and **XGBoost** tend to require fewer pseudo-absences (same number as presence records), as these models can handle higher levels of complexity and do not need as many negative examples to make accurate predictions (Fitzpatrick et al., 2011; Ridgeway, 2021).
#
# Additionally, the selection of pseudo-absence points should reflect **realistic environmental conditions** that the species could potentially occupy, rather than being distributed randomly across the landscape. This ensures that the absence data are ecologically plausible and improve the model's ability to identify suitable habitats for the species. Stratified sampling methods that account for environmental variables such as land cover, elevation, and proximity to water bodies can help in selecting more ecologically relevant pseudo-absences (Barbet-Massin et al., 2012).
#
# In summary, the correct choice of pseudo-absence numbers and their ecological relevance is crucial for building accurate, generalizable species distribution models. By considering the specific needs of each modeling approach and ensuring that pseudo-absence data reflect the species' potential habitat range, the resulting models can provide more reliable predictions of species distribution and inform conservation efforts.
#
#
# ### 5.1 Importing the Necessary Libraries and Data

# %%
import numpy as np
import pandas as pd
import random
import geopandas as gpd
from shapely.geometry import Point
from sklearn.neighbors import NearestNeighbors

# Paths to species presence data files
species_files = {
    "Bufo_bufo": "C:/GIS_Course/MScThesis-MaviSantarelli/data/OccurrenceData/OccurrenceDataperSpecies/Bufo_bufo.shp",
    "Rana_temporaria": "C:/GIS_Course/MScThesis-MaviSantarelli/data/OccurrenceData/OccurrenceDataperSpecies/Rana_temporaria.shp",
    "Lissotriton_helveticus": "C:/GIS_Course/MScThesis-MaviSantarelli/data/OccurrenceData/OccurrenceDataperSpecies/Lissotriton_helveticus.shp",
    "Lissotriton_vulgaris":"C:/GIS_Course/MScThesis-MaviSantarelli/data/OccurrenceData/OccurrenceDataperSpecies/Lissotriton_vulgaris.shp",
    "Triturus_cristatus":"C:/GIS_Course/MScThesis-MaviSantarelli/data/OccurrenceData/OccurrenceDataperSpecies/Triturus_cristatus.shp",
    "Ichthyosaura_alpestris":"C:/GIS_Course/MScThesis-MaviSantarelli/data/OccurrenceData/OccurrenceDataperSpecies/Ichthyosaura_alpestris.shp"
    
}

# Path to the study area shapefile
study_area_path = "C:/GIS_Course/MScThesis-MaviSantarelli/data/StudyArea/study_area.shp"

# %% [markdown]
# ### 5.2  Define the Function to Generate Pseudo-Absences:
# Now, let's define a function to generate pseudo-absences. Pseudo-absences are random points within the study area that are not part of the species’ presence records.

# %%
def generate_pseudo_absences(presence_gdf, total_pseudo_absences, study_area_gdf, species, buffer_distances):
    """
    Generates pseudo-absence points for species, ensuring points are not too close to known presence areas.
    """
    buffer_distance = buffer_distances.get(species, 1000)  # Default to 1000m if species not listed
    presence_buffer = presence_gdf.geometry.buffer(buffer_distance)
    
    random_points = []
    attempts = 0
    while len(random_points) < total_pseudo_absences and attempts < total_pseudo_absences * 2:
        random_point = study_area_gdf.sample(n=1).geometry.iloc[0]
        if not any(random_point.within(buffer) for buffer in presence_buffer):
            random_points.append(random_point)
        attempts += 1

    # Return a GeoDataFrame for the pseudo-absence points
    return gpd.GeoDataFrame(geometry=random_points, crs=study_area_gdf.crs)

# %% [markdown]
# The `generate_pseudo_absences function` creates pseudo-absence points while adhering to key considerations:
#
# * **Presence Buffers**: Ensures pseudo-absences are a minimum distance away from presence points to avoid spatial autocorrelation.
# * **Random Sampling**: Generates random points within the study area.
#
# ### 5.3 Generate Pseudo-Absences for Each Species:
#
# Now, we can generate pseudo-absences for each species.

# %%
import geopandas as gpd

# Load the study area shapefile
study_area_gdf = gpd.read_file(study_area_path)

# Define the number of pseudo-absences per presence point for each species
pseudo_absences_per_species = {
    "Bufo_bufo": 10,
    "Ichthyosaura_alpestris": 5,
    "Lissotriton_helveticus": 10,
    "Lissotriton_vulgaris": 8,
    "Rana_temporaria": 15,
    "Triturus_cristatus": 5
}

# Define species-specific buffer distances based on dispersal ability
buffer_distances = {
    "Bufo_bufo": 5000,  # Common species, buffer of 5 km
    "Ichthyosaura_alpestris": 1000,  # Rare species
    "Lissotriton_helveticus": 1000,  # Moderate dispersal, buffer of 1 km
    "Lissotriton_vulgaris": 1000,  # Moderate dispersal, buffer of 1 km
    "Rana_temporaria": 2000,  # Common species
    "Triturus_cristatus": 1300  # Rare species
}

# Loop through each species and generate pseudo-absences
for species, filepath in species_files.items():
    print(f"Processing {species}...")

    # Load presence data for the species
    presence_gdf = gpd.read_file(filepath)

    # Reproject presence data to match study area CRS
    presence_gdf = presence_gdf.to_crs(study_area_gdf.crs)

    # Get the number of records for the species
    num_records = len(presence_gdf)

    # Retrieve the number of pseudo-absences per presence for the current species
    num_pseudo_absences_per_presence = pseudo_absences_per_species.get(species, 10)

    # Calculate total pseudo-absences needed
    total_pseudo_absences = num_records * num_pseudo_absences_per_presence

    # Generate pseudo-absence data using the generate_pseudo_absences function
    pseudo_absence_gdf = generate_pseudo_absences(
        presence_gdf, total_pseudo_absences, study_area_gdf, species, buffer_distances
    )

    # Save pseudo-absence data to a shapefile
    output_path = f"C:/GIS_Course/MScThesis-MaviSantarelli/data/PseudoAbsences/{species}_pseudo_absences.shp"
    pseudo_absence_gdf.to_file(output_path)
    print(f"Pseudo-absences saved for {species} at {output_path}")
# Out:
# Processing Bufo_bufo...
# Pseudo-absences saved for Bufo_bufo at C:/GIS_Course/MScThesis-MaviSantarelli/data/PseudoAbsences/Bufo_bufo_pseudo_absences.shp
# Processing Rana_temporaria...
# Pseudo-absences saved for Rana_temporaria at C:/GIS_Course/MScThesis-MaviSantarelli/data/PseudoAbsences/Rana_temporaria_pseudo_absences.shp
# Processing Lissotriton_helveticus...
# Pseudo-absences saved for Lissotriton_helveticus at C:/GIS_Course/MScThesis-MaviSantarelli/data/PseudoAbsences/Lissotriton_helveticus_pseudo_absences.shp
# Processing Lissotriton_vulgaris...
# Pseudo-absences saved for Lissotriton_vulgaris at C:/GIS_Course/MScThesis-MaviSantarelli/data/PseudoAbsences/Lissotriton_vulgaris_pseudo_absences.shp
# Processing Triturus_cristatus...
# Pseudo-absences saved for Triturus_cristatus at C:/GIS_Course/MScThesis-MaviSantarelli/data/PseudoAbsences/Triturus_cristatus_pseudo_absences.shp
# Processing Ichthyosaura_alpestris...
# ...

# %% [markdown]
# The script above generates pseudo-absence data for species based on their presence data and specific dispersal abilities. The process involves several key steps:
#
# 1. **Loading the Study Area Shapefile:**
#    The study area shapefile is loaded into a GeoDataFrame. This shapefile represents the geographical boundaries of the study area where species are being assessed.
# 2. **Defining Buffer Distances for Each Species:**
#    A dictionary is created that assigns buffer distances to each species. The buffer distance represents the minimum distance around each presence point where pseudo-absence points cannot be placed. This distance is species-specific and is determined based on the dispersal ability of the species. For example, species with high dispersal abilities, like *Rana temporaria* (Common Frog), have larger buffer distances (e.g., 2000 meters), while species with lower dispersal abilities, like *Ichthyosaura alpestris* (Alpine Newt), have smaller buffer distances (e.g., 500 meters).
# 3. **Processing Each Species:**
#    The code loops through each species listed in the species files. For each species:
#    - The presence data is loaded into a GeoDataFrame.
#    - The CRS (Coordinate Reference System) of the presence data is reprojected to match the CRS of the study area. This ensures that spatial operations are performed correctly.
# 4. **Calculating Pseudo-Absences:**
#    - The number of presence points (records) for the species is determined.
#    - The number of pseudo-absences per presence point is retrieved from a predefined dictionary. If a species is not listed, a default value of 10 pseudo-absences per presence is used.
#    - The total number of pseudo-absences required is calculated by multiplying the number of presence records by the number of pseudo-absences per presence point.
# 5. **Generating the Pseudo-Absence Data:**
#    The function `generate_pseudo_absences()` is called to generate the pseudo-absence data. This function uses the species' presence data, the total number of pseudo-absences, the study area shapefile, and the species-specific buffer distance to ensure that pseudo-absence points are generated within the study area while maintaining the specified distance from the presence points.
# 6. **Saving the Pseudo-Absence Data:**
#    Once the pseudo-absence data is generated, it is saved as a new shapefile in a specified output directory. The saved shapefile can then be used for further spatial analysis, such as species distribution modeling or habitat suitability analysis.
#
# By following this procedure, the code generates a set of pseudo-absence points for each species, which are crucial for performing species distribution modeling and understanding habitat suitability across the study area.

# %% [markdown]
# ## 6. Validate The Data
# #### Objective:
# To ensure that the pseudo-absence points are well-distributed across the study area and do not overlap with presence points. This step is critical for maintaining the integrity of species distribution models (SDMs), as it ensures that the pseudo-absence data are spatially and ecologically meaningful. By adhering to specific guidelines, we aim to create a pseudo-absence dataset that represents areas where the species is likely absent, yet could potentially inhabit based on environmental factors.
#
# #### Justification:
# The quality of pseudo-absence data directly influences the accuracy and predictive power of species distribution models. If pseudo-absence points are poorly distributed or overlap with known presence points, it can introduce substantial bias into the models, distorting the relationship between environmental predictors and species occurrence. This can lead to inaccurate predictions of habitat suitability and, ultimately, undermine the utility of the model for conservation planning and decision-making.
#
# To mitigate such issues, a robust methodology is employed to ensure that pseudo-absence points are spatially distinct from presence points and are distributed across a range of environmental conditions that reflect the broader ecological landscape. The recommendations used in this methodology are grounded in established best practices in species modeling, particularly focusing on avoiding spatial autocorrelation, ensuring environmental representativeness, and minimizing sampling bias.
#
#
# ### 6.1 Checking Count is within appropriate Ratio

# %%
import geopandas as gpd

# Paths to species presence data files
species_files = {
    "Bufo_bufo": "C:/GIS_Course/MScThesis-MaviSantarelli/data/OccurrenceData/OccurrenceDataperSpecies/Bufo_bufo.shp",
    "Rana_temporaria": "C:/GIS_Course/MScThesis-MaviSantarelli/data/OccurrenceData/OccurrenceDataperSpecies/Rana_temporaria.shp",
    "Lissotriton_helveticus": "C:/GIS_Course/MScThesis-MaviSantarelli/data/OccurrenceData/OccurrenceDataperSpecies/Lissotriton_helveticus.shp",
    "Lissotriton_vulgaris": "C:/GIS_Course/MScThesis-MaviSantarelli/data/OccurrenceData/OccurrenceDataperSpecies/Lissotriton_vulgaris.shp",
    "Triturus_cristatus": "C:/GIS_Course/MScThesis-MaviSantarelli/data/OccurrenceData/OccurrenceDataperSpecies/Triturus_cristatus.shp",
    "Ichthyosaura_alpestris": "C:/GIS_Course/MScThesis-MaviSantarelli/data/OccurrenceData/OccurrenceDataperSpecies/Ichthyosaura_alpestris.shp"
}

# Paths to species pseudo-absence data files
pseudo_absence_paths = {
    "Bufo_bufo": "C:/GIS_Course/MScThesis-MaviSantarelli/data/PseudoAbsences/Bufo_bufo_pseudo_absences.shp",
    "Rana_temporaria": "C:/GIS_Course/MScThesis-MaviSantarelli/data/PseudoAbsences/Rana_temporaria_pseudo_absences.shp",
    "Lissotriton_helveticus": "C:/GIS_Course/MScThesis-MaviSantarelli/data/PseudoAbsences/Lissotriton_helveticus_pseudo_absences.shp",
    "Lissotriton_vulgaris": "C:/GIS_Course/MScThesis-MaviSantarelli/data/PseudoAbsences/Lissotriton_vulgaris_pseudo_absences.shp",
    "Triturus_cristatus": "C:/GIS_Course/MScThesis-MaviSantarelli/data/PseudoAbsences/Triturus_cristatus_pseudo_absences.shp",
    "Ichthyosaura_alpestris": "C:/GIS_Course/MScThesis-MaviSantarelli/data/PseudoAbsences/Ichthyosaura_alpestris_pseudo_absences.shp"
}

# Loop through each species and count presence and absence points
for species in species_files:
    print(f"Counting points for {species}...")
    
    # Load the presence data
    presence_gdf = gpd.read_file(species_files[species])
    
    # Load the pseudo-absence data
    absence_gdf = gpd.read_file(pseudo_absence_paths[species])
    
    # Count the number of presence and absence points
    num_presence_points = len(presence_gdf)
    num_absence_points = len(absence_gdf)
    
    # Print the counts
    print(f"{species} Presence Points: {num_presence_points}")
    print(f"{species} Absence Points: {num_absence_points}")
    print("-" * 40)
# Out:
# Counting points for Bufo_bufo...
# Bufo_bufo Presence Points: 716
# Bufo_bufo Absence Points: 4510
# ----------------------------------------
# Counting points for Rana_temporaria...
# Rana_temporaria Presence Points: 1110
# Rana_temporaria Absence Points: 16650
# ----------------------------------------
# Counting points for Lissotriton_helveticus...
# Lissotriton_helveticus Presence Points: 337
# Lissotriton_helveticus Absence Points: 3370
# ----------------------------------------
# Counting points for Lissotriton_vulgaris...
# Lissotriton_vulgaris Presence Points: 60
# Lissotriton_vulgaris Absence Points: 480
# ----------------------------------------
# Counting points for Triturus_cristatus...
# Triturus_cristatus Presence Points: 33
# Triturus_cristatus Absence Points: 165
# ----------------------------------------
# Counting points for Ichthyosaura_alpestris...
# Ichthyosaura_alpestris Presence Points: 33
# Ichthyosaura_alpestris Absence Points: 165
# ...

# %% [markdown]
# ### Species-Specific Pseudo-Absence Counts
#
# **Bufo bufo** (Common Toad) has a target ratio of **10 pseudo-absences per presence point**, but the actual count is significantly lower than expected. This is likely due to the species' large dispersal buffer of **5 km**, which might limit the number of valid locations for pseudo-absence generation within the study area.
#
# ### Potential Causes for Discrepancies in Pseudo-Absence Generation:
#
# 1. **Large Buffer for Common Species (Bufo bufo)**:
#    - A **5 km buffer** for *Bufo bufo* may be too large for the study area. This could mean that pseudo-absence points are being placed outside the area of interest or are too sparse to meet the required ratio.
#    - **Action for Future**: Consider testing smaller buffer distances or restricting pseudo-absences to areas with higher presence density to maintain a representative distribution.
# 2. **Presence Point Clustering**:
#    - The presence points for *Bufo bufo* may be clustered, leaving little room for pseudo-absence points, especially when using a large buffer. **Clustered presence data** can limit the effectiveness of pseudo-absence generation, as points too close to presence locations are excluded from the pseudo-absence generation process.
#    - **Action for Future**: Evaluate **presence data density** (e.g., using **kernel density estimation**) to detect and address clusters in the data. If the presence data is too clustered in certain areas, consider splitting presence records or adjusting buffer sizes to allow for a more balanced distribution of pseudo-absence points.
#
# ### Future Validation
#
# 1. **Density Check for Presence Points**:
#    - Conduct **density checks** (e.g., kernel density estimation) to ensure that presence points are sufficiently distributed across the study area. If areas are overly dense or concentrated, this may skew the pseudo-absence generation process, leading to unreliable models.
#    - This can help in identifying regions with too many or too few presence points and adjusting the pseudo-absence generation strategy accordingly.
# 2. **Cluster Analysis for Pseudo-Absence Validation**:
#    - Perform **cluster analysis** (e.g., **K-means clustering**, **DBSCAN**) on both presence and pseudo-absence points. If pseudo-absence points are found to cluster too close to presence points, it may indicate an issue with buffer size or placement. Proper validation of these points will help avoid model bias and improve the quality of habitat suitability predictions.
#    - **Action**: Use cluster validation techniques to check that the generated pseudo-absences are spread out appropriately and not overlapping with presence records, especially in species with large dispersal distances.
# 3. **Reviewing Buffer Sizes**:
#    - Reevaluate the dispersal buffer distances based on species' life-history traits and actual movement patterns. Consider using literature on species' migration and movement ecology to adjust buffer sizes for more realistic pseudo-absence generation.
#    - **Sources for Buffer Distance Re-evaluation**: Literature from studies on amphibian dispersal, such as Jehle et al. (2011) and O'Brien et al. (2021), can provide guidance on appropriate dispersal distances and buffer sizes for different species.

# %%
# Define buffer zone for proximity exclusion (500 meters)
buffer_distance = 500  # meters
def remove_overlap_with_presence(presence_shapefile, pseudo_absence_shapefile, buffer_distance):
    """
    Removes pseudo-absence points that fall within a buffer distance of presence points.
    """
    # Load the presence and pseudo-absence data
    presence_data = gpd.read_file(presence_shapefile)
    pseudo_absence_data = gpd.read_file(pseudo_absence_shapefile)

    # Ensure both layers are in the same CRS
    if presence_data.crs != pseudo_absence_data.crs:
        pseudo_absence_data = pseudo_absence_data.to_crs(presence_data.crs)

    # Generate a buffer zone around presence points (500 meters)
    presence_buffer = presence_data.geometry.buffer(buffer_distance)

    # Check for overlaps between pseudo-absence points and the buffer zones
    overlap_mask = pseudo_absence_data.geometry.apply(lambda x: any(presence_buffer.intersects(x)))

    # Filter out pseudo-absences that overlap with presence points or their buffers
    pseudo_absence_data_filtered = pseudo_absence_data[~overlap_mask]

    return pseudo_absence_data_filtered

# %% [markdown]
# #### Explanation:
# This step ensures that pseudo-absence points are not placed too close to known occurrences, which would otherwise lead to spatial autocorrelation and model bias. The buffer represents the species' movement distance, and the exclusion helps maintain ecological distinctness between presence and pseudo-absence points.
# This function performs the first validation step by:
#
# * Loading the species' presence and pseudo-absence data.
# * onverting coordinate reference systems (CRS) to match, if necessary.
# * Creating a buffer zone (e.g., 500 meters) around each presence point to exclude any pseudo-absence points within this buffer zone.
# * Using a spatial intersection check (`intersects`) to find and exclude pseudo-absence points that fall inside the buffer.
#
# ### 6.3 Mask Out Areas Likely Suitable for the Species (e.g., Wetlands)
# **Objective**:
# Remove pseudo-absence points from areas that are unsuitable for the species, such as wetlands or other habitat types where the species would not typically be found.

# %% [markdown]
# ## 7. Integrate the Data

# %% [markdown]
# # References
#
# 1. Barbet-Massin, M., Jiguet, F., Albert, C. H., & Thuiller, W. (2012). Selecting pseudo-absence data for species distribution models: how, where, and how many? *Methods in Ecology and Evolution*, 3(2), 327–338. [DOI:10.1111/j.2041-210X.2011.00172.x](https://doi.org/10.1111/j.2041-210X.2011.00172.x)
#
# 2. Elith, J., & Leathwick, J. R. (2009). Species distribution models: ecological explanation and prediction across space and time. *Annual Review of Ecology, Evolution, and Systematics*, 40, 677–697. [DOI:10.1146/annurev.ecolsys.110308.120159](https://doi.org/10.1146/annurev.ecolsys.110308.120159)
#
# 3. Franklin, J. (2010). *Mapping species distributions: Spatial inference and prediction.* Cambridge University Press.
#
# 4. Guisan, A., & Thuiller, W. (2005). Predicting species distribution: Offering more than simple habitat models. *Ecology Letters*, 8(9), 993–1009. [DOI:10.1111/j.1461-0248.2005.00792.x](https://doi.org/10.1111/j.1461-0248.2005.00792.x)
#
# 5. Jehle, R., et al. (2011). Inter-pond distance, species traits, and amphibian declines: An analysis of 16 species across Europe. *Ecological Applications*, 21(1), 128–140. [DOI:10.1890/09-2210.1](https://doi.org/10.1890/09-2210.1)
#
# 6. Lobo, J. M., Jiménez-Valverde, A., & Hortal, J. (2010). The uncertain nature of absences and the need for caution when choosing pseudo-absence locations in species distribution modelling. *Ecography*, 33(1), 103–114. [DOI:10.1111/j.1600-0587.2009.06156.x](https://doi.org/10.1111/j.1600-0587.2009.06156.x)
#
# 7. Olsen, A. R. (2006). Framework for assessing habitat loss in relation to amphibian population declines. *Environmental Monitoring and Assessment*, 113(1), 23–40. [DOI:10.1007/s10661-005-9091-8](https://doi.org/10.1007/s10661-005-9091-8)
#
# 8. Phillips, S. J., Anderson, R. P., & Schapire, R. E. (2006). Maximum entropy modeling of species geographic distributions. *Ecological Modelling*, 190(3–4), 231–259. [DOI:10.1016/j.ecolmodel.2005.03.026](https://doi.org/10.1016/j.ecolmodel.2005.03.026)
#
# 9. Raes, N., & ter Steege, H. (2007). A null-model for significance testing of presence-only species distribution models. *Ecography*, 30(5), 727–736. [DOI:10.1111/j.2007.0906-7590.05177.x](https://doi.org/10.1111/j.2007.0906-7590.05177.x)
#
# 10. Radosavljevic, A., & Anderson, R. P. (2014). Making better Maxent models of species distributions: Complexity, overfitting, and evaluation. *Journal of Biogeography*, 41(4), 629–643. [DOI:10.1111/jbi.12227](https://doi.org/10.1111/jbi.12227)
#
# 11. Zurell, D., Elith, J., & Schröder, B. (2020). A standard protocol for reporting species distribution models. *Ecography*, 43(4), 539–548. [DOI:10.1111/ecog.04960](https://doi.org/10.1111/ecog.04960)
#
# 12. O'Brien, D. L., et al. (2021). Colonization and dispersal patterns of amphibian species in new ponds Implications for habitat connectivity. *Biological Conservation*.
