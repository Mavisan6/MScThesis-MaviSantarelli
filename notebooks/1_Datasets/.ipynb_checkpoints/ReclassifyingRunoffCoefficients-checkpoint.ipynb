# %% [markdown]
# # Reclassifying Land Cover into Runoff Coefficient Values
#
# ## Step 1: Load Required Libraries

# %%
import rasterio
import numpy as np
from rasterio.plot import show
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 2: Load the Land Cover Raster

# %%
# Specify the path to your land cover raster file
land_cover_path = "C:/GIS_Course/MScThesis-MaviSantarelli/data/Predictors/RunoffCoefficient/ESRILandCover_2_Resample.tif"

# Open the raster
with rasterio.open(land_cover_path) as src:
    land_cover = src.read(1)  # Read the first band
    profile = src.profile  # Save the profile for later
    no_data_value = src.nodata  # Get the no-data value if set

# Visualize the land cover raster
plt.figure(figsize=(8, 6))
show(land_cover, cmap='tab10', title="Original Land Cover")
plt.show()

# %% [markdown]
# ## Step 3: Create a Reclassification Map

# %%
# Define the reclassification mapping
reclass_map = {
    1: 1.00,   # Water
    2: 0.15,   # Trees
    11: 0.30,  # Rangeland
    4: 0.80,   # Flooded Vegetation
    5: 0.40,   # Crops
    7: 0.85,   # Built-Up Area
    8: 0.60,   # Bare Ground
    9: 0.60,   # Snow/Ice
    10: np.nan # Clouds, assign no-data (or handle separately later)
}

# %% [markdown]
# ## Step 4: Reclassify the Raster

# %%
# Ensure the array is of float type to allow np.nan values
reclassified = np.full(land_cover.shape, np.nan, dtype='float32')  # Initialize with np.nan

# Apply the reclassification
for lc_value, runoff_value in reclass_map.items():
    reclassified[land_cover == lc_value] = runoff_value

# Handle no-data (if necessary)
if no_data_value is not None:
    reclassified[land_cover == no_data_value] = np.nan  # Assign no-data

# %% [markdown]
# ## Step 5: Save the Reclassified Raster

# %%
# Step 5: Save the reclassified raster
from rasterio import Affine

# Define the metadata for the output raster
out_meta = src.meta.copy()  # Use the original metadata from the input raster
out_meta.update({
    "dtype": "float32",  # Ensure the data type matches the reclassified array
    "nodata": np.nan,    # Define no-data value
})

# Save the reclassified raster
output_path = "C:/GIS_Course/MScThesis-MaviSantarelli/data/Predictors/RunoffCoefficient/reclassified_runoff_coefficients.tif"
with rasterio.open(output_path, "w", **out_meta) as dst:
    dst.write(reclassified, 1)  # Write the reclassified array to the first band
print(f"Reclassified runoff coefficients saved to {output_path}")
# Out:
# Reclassified runoff coefficients saved to C:/GIS_Course/MScThesis-MaviSantarelli/data/Predictors/RunoffCoefficient/reclassified_runoff_coefficients.tif

# %% [markdown]
# ## Step 6: Verify the Output

# %%
# Step 6: Verify the output by loading and displaying it
import matplotlib.pyplot as plt

# Load the saved raster to check it
with rasterio.open(output_path) as dataset:
    data = dataset.read(1)

# Plot the reclassified raster
plt.figure(figsize=(10, 6))
plt.imshow(data, cmap='viridis', interpolation='none')
plt.colorbar(label="Runoff Coefficient")
plt.title("Reclassified Runoff Coefficient Raster")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# ## Step 7: Check No Data Values
# ### 1. Analyze No-Data Pixels in the Raster

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Load the raster
raster_path = "C:/GIS_Course/MScThesis-MaviSantarelli/data/Predictors/RunoffCoefficient/reclassified_runoff_coefficients.tif"
with rasterio.open(raster_path) as src:
    data = src.read(1)  # Read the first band
    profile = src.profile

# Step 2: Identify no-data pixels
no_data_value = src.nodata  # Get no-data value from metadata
if no_data_value is None:
    no_data_value = np.nan  # Default to np.nan if no-data value is not set

no_data_mask = (data == no_data_value) | np.isnan(data)  # Create a mask for no-data pixels

# Step 3: Calculate statistics
total_pixels = data.size
no_data_pixels = np.sum(no_data_mask)
no_data_percentage = (no_data_pixels / total_pixels) * 100

# Step 4: Display the results
print(f"Total pixels: {total_pixels}")
print(f"No-data pixels: {no_data_pixels}")
print(f"Percentage of no-data pixels: {no_data_percentage:.2f}%")

# Step 5: Visualize the no-data distribution
plt.figure(figsize=(10, 8))
plt.imshow(no_data_mask, cmap='gray', interpolation='nearest')
plt.title("No-Data Pixel Distribution")
plt.colorbar(label="No-Data (1 = True, 0 = False)")
plt.show()
# Out:
# Total pixels: 41947248
# No-data pixels: 23476817
# Percentage of no-data pixels: 55.97%

# %% [markdown]
# ### 2. Crop to AOI

# %%
import geopandas as gpd

# Load the shapefile
aoi_shapefile_path = "C:/GIS_Course/MScThesis-MaviSantarelli/data/StudyArea/Study_Area.shp"
aoi_gdf = gpd.read_file(aoi_shapefile_path)

# Check if there are multiple polygons
print("Number of polygons in AOI shapefile:", len(aoi_gdf))
# Out:
# Number of polygons in AOI shapefile: 38

# %%
# Merge all polygons into one
aoi_polygon = aoi_gdf.unary_union
# Check if there are multiple polygons

# %%
import rasterio

# Open the raster to get its CRS
raster_path = "C:/GIS_Course/MScThesis-MaviSantarelli/data/Predictors/RunoffCoefficient/reclassified_runoff_coefficients.tif"
with rasterio.open(raster_path) as src:
    raster_crs = src.crs

# Reproject the AOI to match the raster CRS
aoi_gdf = aoi_gdf.to_crs(raster_crs)

# %%
from rasterio.mask import mask

# Mask the raster with the AOI polygon
with rasterio.open(raster_path) as src:
    out_image, out_transform = mask(src, [aoi_polygon], crop=True)

# Save the cropped raster (optional)
from rasterio import Affine
from rasterio.io import MemoryFile

out_meta = src.meta.copy()
out_meta.update({
    "driver": "GTiff",
    "height": out_image.shape[1],
    "width": out_image.shape[2],
    "transform": out_transform
})

with rasterio.open("cropped_raster.tif", "w", **out_meta) as dest:
    dest.write(out_image)

# %%
from shapely.geometry import shape, box

# Convert the raster bounds to a shapely box
raster_polygon = box(*raster_bounds)

# Print raster and AOI bounds
print("Raster bounds:", raster_bounds)
print("AOI bounds:", aoi_polygon.bounds)

# Calculate the overlap area
overlap_area = aoi_polygon.intersection(raster_polygon).area
print("Overlap area:", overlap_area)
# Out:
# Raster bounds: BoundingBox(left=187322.10163310927, bottom=550343.5372726114, right=387452.10163310927, top=738983.5372726114)
# AOI bounds: (195971.59999999963, 554954.5, 387005.4000000004, 734058.0)
# Overlap area: 16624059427.322615

# %% [markdown]
# ### 3. Recalculate No-Data Statistics

# %%
with rasterio.open(cropped_raster_path) as src:
    cropped_data = src.read(1)
    no_data_value = src.nodata

# Create a mask for no-data values
cropped_no_data_mask = (cropped_data == no_data_value) | np.isnan(cropped_data)

# Calculate statistics
total_cropped_pixels = cropped_data.size
no_data_cropped_pixels = np.sum(cropped_no_data_mask)
no_data_cropped_percentage = (no_data_cropped_pixels / total_cropped_pixels) * 100

# Print results
print(f"Total cropped pixels: {total_cropped_pixels}")
print(f"No-data pixels (cropped): {no_data_cropped_pixels}")
print(f"Percentage of no-data pixels (cropped): {no_data_cropped_percentage:.2f}%")
# Out:
# Total cropped pixels: 38029299
# No-data pixels (cropped): 19558913
# Percentage of no-data pixels (cropped): 51.43%

# %%
from shapely.geometry import box
from rasterio.features import bounds

# Get raster bounds
with rasterio.open(cropped_raster_path) as src:
    raster_bounds = box(*src.bounds)

# Get AOI bounds
aoi_bounds = aoi.geometry.unary_union.bounds

# Check overlap
print(f"Raster bounds: {raster_bounds}")
print(f"AOI bounds: {aoi_bounds}")
print(f"Overlap area: {raster_bounds.intersection(box(*aoi_bounds)).area}")
# Out:
# Raster bounds: POLYGON ((387032.10163310927 554933.5372726114, 387032.10163310927 734063.5372726114, 195962.10163310927 734063.5372726114, 195962.10163310927 554933.5372726114, 387032.10163310927 554933.5372726114))
# AOI bounds: (195971.59999999963, 554954.5, 387005.4000000004, 734058.0)
# Overlap area: 34214822198.300133

# %%
import numpy as np
from shapely.geometry import Polygon
import rasterio
from rasterio.features import geometry_mask

with rasterio.open(cropped_raster_path) as src:
    raster_data = src.read(1)
    raster_transform = src.transform
    nodata_value = src.nodata

# Mask to AOI
aoi_polygon = Polygon([(195971.6, 554954.5), (387005.4, 554954.5), 
                       (387005.4, 734058.0), (195971.6, 734058.0), 
                       (195971.6, 554954.5)])
aoi_mask = geometry_mask([aoi_polygon], transform=raster_transform, invert=True, out_shape=raster_data.shape)

# Identify NoData pixels
nodata_mask = (raster_data == nodata_value) & aoi_mask

print(f"NoData Pixels Inside AOI: {np.count_nonzero(nodata_mask)}")
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File rasterio\\_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# File rasterio\\_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio\\_err.pyx:221, in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: path_to_raster.tif: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[15], line 8
#       6 # Load raster
#       7 raster_path = "path_to_raster.tif"
# ----> 8 with rasterio.open(raster_path) as src:
#       9     raster_data = src.read(1)
#      10     raster_transform = src.transform
#
# File ~\anaconda3\envs\MscThesis\lib\site-packages\rasterio\env.py:451, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     448     session = DummySession()
# ...
